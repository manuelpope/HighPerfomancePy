# %% [markdown]
# <a href="https://colab.research.google.com/github/manuelpope/HighPerfomancePy/blob/master/Section7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Dask example
#pip install dask["complete"]
import dask.array as da
import numpy as np
from dask import delayed
ds.core.add(4.5,6)
arr1= np.random.random(10)
arr1

daskArrray = da.random.random(10,chunks=3)
daskArrray
daskArrray.compute()
daskArrray.chunks
#este array son los lenght de el split

daskArrray2= da.from_array(arr1, chunks=4)
daskArrray2.compute()

dar3 = da.random.random(1000000, chunks=1000)
dar4 = da.random.random(1000000, chunks=1000)
dar5 = da.add(dar3,dar4)

dar5.compute()
dar5
@delayed
def op1(x,y,z):
  return x-y + 2*z
@delayed
def op2(x,y,z):
  return x+y + op1(x,y,z)
@delayed
def op3(x,y,z):
  return x+ op1(x,y,z) + z


x= np.random.random(10)
y= np.random.random(10)
z= np.random.random(10)

finalResult = []
finalResult = [op1(x,op1(x,y,z),z)+ op2(op1(x,y,z),y,z)+ op3(x,y,op1(x,y,z))]
finalSum= delayed(np.sum)(finalResult)
finalSum.compute()
finalSum.visualize()
